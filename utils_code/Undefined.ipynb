# %%
# Dosya adlarını yeniden yazma.

"""import os

folder = "/home/cemal/My_Academic_Projects/Fish_Projects/utils_code/Scenario-3/3/Images"
files = sorted([f for f in os.listdir(folder) if f.endswith(".png")])

for i, filename in enumerate(files):
    new_name = f"Frame_3_3_{i+1}.png"
    os.rename(os.path.join(folder, filename), os.path.join(folder, new_name))"""
# Out:
# 'import os\n\nfolder = "/home/cemal/My_Academic_Projects/Fish_Projects/utils_code/Scenario-3/3/Images"\nfiles = sorted([f for f in os.listdir(folder) if f.endswith(".png")])\n\nfor i, filename in enumerate(files):\n    new_name = f"Frame_3_3_{i+1}.png"\n    os.rename(os.path.join(folder, filename), os.path.join(folder, new_name))'

# %%
# Centered_Images oluşturma kodu

"""import os
import cv2
import numpy as np

input_folder = "/home/cemal/My_Academic_Projects/Scenario-1/5/labeled_images"
output_folder = "/home/cemal/My_Academic_Projects/Scenario-1/5/centered_images"
os.makedirs(output_folder, exist_ok=True)

canvas_size = 1280

for filename in os.listdir(input_folder):
    if filename.endswith(".png"):
        img_path = os.path.join(input_folder, filename)
        img = cv2.imread(img_path)

        h, w = img.shape[:2]
        canvas = np.zeros((canvas_size, canvas_size, 3), dtype=np.uint8)

        y_offset = (canvas_size - h) // 2
        x_offset = (canvas_size - w) // 2

        canvas[y_offset:y_offset + h, x_offset:x_offset + w] = img

        out_path = os.path.join(output_folder, filename)
        cv2.imwrite(out_path, canvas)"""
